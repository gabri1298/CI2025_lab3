# %% [markdown]
# Copyright **`(c)`** 2025 Giovanni Squillero `<giovanni.squillero@polito.it>`
# [`https://github.com/squillero/computational-intelligence`](https://github.com/squillero/computational-intelligence)
# Free under certain conditions — see the [`license`](https://github.com/squillero/computational-intelligence/blob/master/LICENSE.md) for details.

# %%
from itertools import product, combinations
import numpy as np
import networkx as nx
from icecream import ic
from tqdm.auto import tqdm

# %%
import numpy as np
from itertools import product

def create_problem(
    size: int,
    *,
    density: float = 1.0,
    negative_values: bool = False,
    noise_level: float = 0.0,
    seed: int = 42,
) -> np.ndarray:
    """Problem generator for Lab3: creates a weighted directed graph matrix."""
    rng = np.random.default_rng(seed)

    coords = rng.random(size=(size, 2))

    problem = rng.random((size, size))

    if negative_values:
        problem = problem * 2 - 1

    problem *= noise_level

    for a, b in product(range(size), repeat=2):
        if rng.random() < density:
            dist = np.linalg.norm(coords[a] - coords[b])
            problem[a, b] += dist
        else:
            problem[a, b] = np.inf

    np.fill_diagonal(problem, 0)

    return (problem * 1_000).round()

# %%
problem = create_problem(20, density=0.15, noise_level=10, negative_values=False)

# %%
masked = np.ma.masked_array(problem, mask=np.isinf(problem))
G = nx.from_numpy_array(masked, create_using=nx.DiGraph)

# %%
has_negative = any(data['weight'] < 0 for _, _, data in G.edges(data=True))

for s, d in combinations(range(problem.shape[0]), 2):
    try:
        if has_negative:
            path = nx.bellman_ford_path(G, source=s, target=d, weight='weight')
        else:
            path = nx.dijkstra_path(G, source=s, target=d, weight='weight')

        cost = nx.path_weight(G, path, weight='weight')
    except nx.NetworkXNoPath:
        path = None
        cost = np.inf
    except nx.NetworkXUnbounded:
        path = None
        cost = -np.inf

    ic(s, d, cost)

# %% [markdown]
# # Lab 3: All-Pairs Shortest Paths
# This section adds utilities to generate graphs, compute all-pairs shortest paths (using NetworkX baselines), and collect global statistics across all parameter combinations. Global stats only, no path prints.

# %%
import time
import math

def build_graph(problem: np.ndarray) -> nx.DiGraph:
    masked = np.ma.masked_array(problem, mask=np.isinf(problem))
    return nx.from_numpy_array(masked, create_using=nx.DiGraph)


def all_pairs_shortest_path_lengths(G: nx.DiGraph, weight: str = "weight"):
    """Return (distances_dict, info_dict)."""
    t0 = time.perf_counter()
    negative_cycle = False
    algo = None

    # Controllo se ci sono pesi negativi
    has_negative = any(data[weight] < 0 for _, _, data in G.edges(data=True))

    try:
        if has_negative:
            algo = "bellman-ford"
            dists = dict(nx.all_pairs_bellman_ford_path_length(G, weight=weight))
        else:
            algo = "dijkstra"
            dists = dict(nx.all_pairs_dijkstra_path_length(G, weight=weight))
    except nx.NetworkXUnbounded:
        dists = {}
        negative_cycle = True

    secs = time.perf_counter() - t0
    return dists, {"algorithm": algo, "negative_cycle": negative_cycle, "seconds": secs}

def compute_global_stats(dists: dict) -> dict:
    total_pairs = 0
    reachable = 0
    pos_reachable = 0
    neg_infinite = 0
    finite_vals = []

    for s, dm in dists.items():
        for t, d in dm.items():
            if s == t:
                continue
            total_pairs += 1
            if isinstance(d, float) and math.isinf(d):
                if d < 0:
                    neg_infinite += 1
                continue
            if d == -np.inf:
                neg_infinite += 1
                continue
            if isinstance(d, float) and np.isfinite(d):
                reachable += 1
                finite_vals.append(d)
                if d > 0:
                    pos_reachable += 1

    stats = {
        "total_pairs": total_pairs,
        "reachable_pairs": reachable,
        "reachable_ratio": (reachable / total_pairs) if total_pairs else 0.0,
        "positive_pairs": pos_reachable,
        "positive_ratio": (pos_reachable / total_pairs) if total_pairs else 0.0,
        "neg_inf_pairs": neg_infinite,
    }
    if finite_vals:
        arr = np.array(finite_vals, dtype=float)
        stats.update({
            "mean": float(arr.mean()),
            "median": float(np.median(arr)),
            "min": float(arr.min()),
            "max": float(arr.max()),
        })
    else:
        stats.update({"mean": np.nan, "median": np.nan, "min": np.nan, "max": np.nan})
    return stats

# %%
from itertools import product


SIZES = [10, 20, 50, 100, 200, 500, 1000]
DENSITIES = [0.2, 0.5, 0.8, 1.0]
NOISE_LEVELS = [0.0, 0.1, 0.5, 0.8]
NEGATIVE_FLAGS = [False, True]



results = []

param_grid = list(product(SIZES, DENSITIES, NOISE_LEVELS, NEGATIVE_FLAGS))
print(f"Total combinations: {len(param_grid)}")

for size, density, noise_level, negative_values in tqdm(param_grid):
   
    problem = create_problem(
        size,
        density=density,
        negative_values=negative_values,
        noise_level=noise_level,
        seed=42,
    )
    G = build_graph(problem)
    dists, info = all_pairs_shortest_path_lengths(G, negative_values)
    stats = compute_global_stats(dists)

    row = {
        "size": size,
        "density": density,
        "noise_level": noise_level,
        "negative_values": negative_values,
        "algorithm": info.get("algorithm"),
        "negative_cycle": info.get("negative_cycle"),
        "seconds": info.get("seconds"),
        **stats,
    }
    results.append(row)
    print(
        f"size={size:4d} dens={density:.1f} noise={noise_level:.1f} neg={negative_values} | "
        f"algo={row['algorithm']:<12} neg_cycle={row['negative_cycle']} sec={row['seconds']:.3f} | "
        f"reach={row['reachable_ratio']:.3f} pos={row['positive_ratio']:.3f} mean={row['mean']}"
    )

print(f"Collected results: {len(results)} rows")
# Out:
# Total combinations: 224
#   0%|          | 0/224 [00:00<?, ?it/s]
# size=  10 dens=0.2 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=0.000 | reach=1.000 pos=1.000 mean=1213.5802469135801
# size=  10 dens=0.2 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=0.000 | reach=1.000 pos=1.000 mean=1213.5802469135801
# size=  10 dens=0.2 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=0.000 | reach=1.000 pos=1.000 mean=1314.9506172839506
# size=  10 dens=0.2 noise=0.1 neg=True | algo=bellman-ford neg_cycle=False sec=0.000 | reach=1.000 pos=1.000 mean=1206.9382716049383
# size=  10 dens=0.2 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=0.000 | reach=1.000 pos=1.000 mean=1711.2345679012346
# size=  10 dens=0.2 noise=0.5 neg=True | algo=bellman-ford neg_cycle=False sec=0.000 | reach=1.000 pos=0.963 mean=1079.8024691358025
# size=  10 dens=0.2 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=0.000 | reach=1.000 pos=1.000 mean=2004.3827160493827
# size=  10 dens=0.2 noise=0.8 neg=True | algo=bellman-ford neg_cycle=False sec=0.000 | reach=1.000 pos=0.889 mean=946.8641975308642
# size=  10 dens=0.5 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=0.000 | reach=1.000 pos=1.000 mean=745.5222222222222
# size=  10 dens=0.5 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=0.000 | reach=1.000 pos=1.000 mean=745.5222222222222
# size=  10 dens=0.5 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=0.000 | reach=1.000 pos=1.000 mean=826.9777777777778
# size=  10 dens=0.5 noise=0.1 neg=True | algo=bellman-ford neg_cycle=False sec=0.000 | reach=1.000 pos=1.000 mean=749.9222222222222
# size=  10 dens=0.5 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=0.000 | reach=1.000 pos=1.000 mean=1128.9777777777779
# size=  10 dens=0.5 noise=0.5 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size=  10 dens=0.5 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=0.000 | reach=1.000 pos=1.000 mean=1344.3666666666666
# size=  10 dens=0.5 noise=0.8 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size=  10 dens=0.8 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=0.000 | reach=1.000 pos=1.000 mean=553.9111111111112
# size=  10 dens=0.8 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=0.000 | reach=1.000 pos=1.000 mean=553.9111111111112
# size=  10 dens=0.8 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=0.000 | reach=1.000 pos=1.000 mean=606.9111111111112
# size=  10 dens=0.8 noise=0.1 neg=True | algo=bellman-ford neg_cycle=False sec=0.000 | reach=1.000 pos=1.000 mean=514.0555555555555
# size=  10 dens=0.8 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=0.000 | reach=1.000 pos=1.000 mean=802.8222222222222
# size=  10 dens=0.8 noise=0.5 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size=  10 dens=0.8 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=0.000 | reach=1.000 pos=1.000 mean=945.9666666666667
# size=  10 dens=0.8 noise=0.8 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size=  10 dens=1.0 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=0.000 | reach=1.000 pos=1.000 mean=532.6222222222223
# size=  10 dens=1.0 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=0.000 | reach=1.000 pos=1.000 mean=532.6222222222223
# size=  10 dens=1.0 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=0.000 | reach=1.000 pos=1.000 mean=578.7777777777778
# size=  10 dens=1.0 noise=0.1 neg=True | algo=bellman-ford neg_cycle=False sec=0.000 | reach=1.000 pos=1.000 mean=489.22222222222223
# size=  10 dens=1.0 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=0.000 | reach=1.000 pos=1.000 mean=747.6444444444444
# size=  10 dens=1.0 noise=0.5 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size=  10 dens=1.0 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=0.000 | reach=1.000 pos=1.000 mean=864.6888888888889
# size=  10 dens=1.0 noise=0.8 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size=  20 dens=0.2 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=0.001 | reach=1.000 pos=1.000 mean=929.2868421052632
# size=  20 dens=0.2 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=0.001 | reach=1.000 pos=1.000 mean=929.2868421052632
# size=  20 dens=0.2 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=0.001 | reach=1.000 pos=1.000 mean=1053.1
# size=  20 dens=0.2 noise=0.1 neg=True | algo=bellman-ford neg_cycle=False sec=0.001 | reach=1.000 pos=1.000 mean=934.3578947368421
# size=  20 dens=0.2 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=0.001 | reach=1.000 pos=1.000 mean=1500.6157894736841
# size=  20 dens=0.2 noise=0.5 neg=True | algo=bellman-ford neg_cycle=False sec=0.001 | reach=1.000 pos=0.961 mean=711.9421052631579
# size=  20 dens=0.2 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=0.001 | reach=1.000 pos=1.000 mean=1812.3447368421052
# size=  20 dens=0.2 noise=0.8 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size=  20 dens=0.5 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=0.001 | reach=1.000 pos=1.000 mean=596.5684210526316
# size=  20 dens=0.5 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=0.001 | reach=1.000 pos=1.000 mean=596.5684210526316
# size=  20 dens=0.5 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=0.001 | reach=1.000 pos=1.000 mean=676.5
# size=  20 dens=0.5 noise=0.1 neg=True | algo=bellman-ford neg_cycle=False sec=0.001 | reach=1.000 pos=1.000 mean=580.6763157894737
# size=  20 dens=0.5 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=0.001 | reach=1.000 pos=1.000 mean=946.2052631578947
# size=  20 dens=0.5 noise=0.5 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size=  20 dens=0.5 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=0.001 | reach=1.000 pos=1.000 mean=1120.2368421052631
# size=  20 dens=0.5 noise=0.8 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size=  20 dens=0.8 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=0.002 | reach=1.000 pos=1.000 mean=546.4657894736843
# size=  20 dens=0.8 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=0.003 | reach=1.000 pos=1.000 mean=546.4657894736843
# size=  20 dens=0.8 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=0.002 | reach=1.000 pos=1.000 mean=604.7052631578947
# size=  20 dens=0.8 noise=0.1 neg=True | algo=bellman-ford neg_cycle=False sec=0.003 | reach=1.000 pos=0.997 mean=503.2657894736842
# size=  20 dens=0.8 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=0.001 | reach=1.000 pos=1.000 mean=806.7789473684211
# size=  20 dens=0.8 noise=0.5 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size=  20 dens=0.8 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=0.001 | reach=1.000 pos=1.000 mean=935.3657894736842
# size=  20 dens=0.8 noise=0.8 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size=  20 dens=1.0 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=0.002 | reach=1.000 pos=1.000 mean=536.2052631578947
# size=  20 dens=1.0 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=0.002 | reach=1.000 pos=1.000 mean=536.2052631578947
# size=  20 dens=1.0 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=0.002 | reach=1.000 pos=1.000 mean=583.1578947368421
# size=  20 dens=1.0 noise=0.1 neg=True | algo=bellman-ford neg_cycle=False sec=0.002 | reach=1.000 pos=0.997 mean=478.65
# size=  20 dens=1.0 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=0.002 | reach=1.000 pos=1.000 mean=746.8763157894737
# size=  20 dens=1.0 noise=0.5 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size=  20 dens=1.0 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=0.002 | reach=1.000 pos=1.000 mean=853.1394736842105
# size=  20 dens=1.0 noise=0.8 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size=  50 dens=0.2 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=0.006 | reach=1.000 pos=1.000 mean=744.0367346938775
# size=  50 dens=0.2 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=0.008 | reach=1.000 pos=1.000 mean=744.0367346938775
# size=  50 dens=0.2 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=0.006 | reach=1.000 pos=1.000 mean=845.1297959183673
# size=  50 dens=0.2 noise=0.1 neg=True | algo=bellman-ford neg_cycle=False sec=0.008 | reach=1.000 pos=1.000 mean=709.6677551020408
# size=  50 dens=0.2 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=0.006 | reach=1.000 pos=1.000 mean=1178.462857142857
# size=  50 dens=0.2 noise=0.5 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size=  50 dens=0.2 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=0.006 | reach=1.000 pos=1.000 mean=1390.9187755102041
# size=  50 dens=0.2 noise=0.8 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size=  50 dens=0.5 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=0.013 | reach=1.000 pos=1.000 mean=528.1967346938776
# size=  50 dens=0.5 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=0.013 | reach=1.000 pos=1.000 mean=528.1967346938776
# size=  50 dens=0.5 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=0.012 | reach=1.000 pos=1.000 mean=597.1155102040816
# size=  50 dens=0.5 noise=0.1 neg=True | algo=bellman-ford neg_cycle=False sec=0.019 | reach=1.000 pos=0.998 mean=458.60979591836735
# size=  50 dens=0.5 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=0.013 | reach=1.000 pos=1.000 mean=807.0567346938775
# size=  50 dens=0.5 noise=0.5 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size=  50 dens=0.5 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=0.013 | reach=1.000 pos=1.000 mean=935.6689795918368
# size=  50 dens=0.5 noise=0.8 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size=  50 dens=0.8 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=0.018 | reach=1.000 pos=1.000 mean=502.74448979591835
# size=  50 dens=0.8 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=0.018 | reach=1.000 pos=1.000 mean=502.74448979591835
# size=  50 dens=0.8 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=0.019 | reach=1.000 pos=1.000 mean=552.9383673469388
# size=  50 dens=0.8 noise=0.1 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size=  50 dens=0.8 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=0.019 | reach=1.000 pos=1.000 mean=709.433469387755
# size=  50 dens=0.8 noise=0.5 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size=  50 dens=0.8 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=0.019 | reach=1.000 pos=1.000 mean=806.0734693877552
# size=  50 dens=0.8 noise=0.8 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size=  50 dens=1.0 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=0.022 | reach=1.000 pos=1.000 mean=498.5640816326531
# size=  50 dens=1.0 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=0.022 | reach=1.000 pos=1.000 mean=498.5640816326531
# size=  50 dens=1.0 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=0.022 | reach=1.000 pos=1.000 mean=540.6812244897959
# size=  50 dens=1.0 noise=0.1 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size=  50 dens=1.0 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=0.023 | reach=1.000 pos=1.000 mean=672.8738775510204
# size=  50 dens=1.0 noise=0.5 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size=  50 dens=1.0 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=0.023 | reach=1.000 pos=1.000 mean=755.7138775510205
# size=  50 dens=1.0 noise=0.8 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size= 100 dens=0.2 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=0.044 | reach=1.000 pos=1.000 mean=609.8727272727273
# size= 100 dens=0.2 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=0.052 | reach=1.000 pos=1.000 mean=609.8727272727273
# size= 100 dens=0.2 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=0.043 | reach=1.000 pos=1.000 mean=712.0119191919192
# size= 100 dens=0.2 noise=0.1 neg=True | algo=bellman-ford neg_cycle=False sec=0.063 | reach=1.000 pos=0.999 mean=553.0583838383839
# size= 100 dens=0.2 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=0.042 | reach=1.000 pos=1.000 mean=1023.319898989899
# size= 100 dens=0.2 noise=0.5 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size= 100 dens=0.2 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=0.044 | reach=1.000 pos=1.000 mean=1213.6675757575758
# size= 100 dens=0.2 noise=0.8 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size= 100 dens=0.5 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=0.095 | reach=1.000 pos=1.000 mean=524.030101010101
# size= 100 dens=0.5 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=0.093 | reach=1.000 pos=1.000 mean=524.030101010101
# size= 100 dens=0.5 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=0.096 | reach=1.000 pos=1.000 mean=585.8625252525253
# size= 100 dens=0.5 noise=0.1 neg=True | algo=bellman-ford neg_cycle=True sec=0.001 | reach=0.000 pos=0.000 mean=nan
# size= 100 dens=0.5 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=0.093 | reach=1.000 pos=1.000 mean=759.680909090909
# size= 100 dens=0.5 noise=0.5 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size= 100 dens=0.5 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=0.098 | reach=1.000 pos=1.000 mean=862.5110101010101
# size= 100 dens=0.5 noise=0.8 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size= 100 dens=0.8 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=0.142 | reach=1.000 pos=1.000 mean=512.5890909090909
# size= 100 dens=0.8 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=0.137 | reach=1.000 pos=1.000 mean=512.5890909090909
# size= 100 dens=0.8 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=0.143 | reach=1.000 pos=1.000 mean=556.6659595959596
# size= 100 dens=0.8 noise=0.1 neg=True | algo=bellman-ford neg_cycle=True sec=0.001 | reach=0.000 pos=0.000 mean=nan
# size= 100 dens=0.8 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=0.146 | reach=1.000 pos=1.000 mean=681.2401010101011
# size= 100 dens=0.8 noise=0.5 neg=True | algo=bellman-ford neg_cycle=True sec=0.001 | reach=0.000 pos=0.000 mean=nan
# size= 100 dens=0.8 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=0.149 | reach=1.000 pos=1.000 mean=754.6404040404041
# size= 100 dens=0.8 noise=0.8 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size= 100 dens=1.0 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=0.182 | reach=1.000 pos=1.000 mean=510.6440404040404
# size= 100 dens=1.0 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=0.170 | reach=1.000 pos=1.000 mean=510.6440404040404
# size= 100 dens=1.0 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=0.178 | reach=1.000 pos=1.000 mean=546.8446464646464
# size= 100 dens=1.0 noise=0.1 neg=True | algo=bellman-ford neg_cycle=True sec=0.001 | reach=0.000 pos=0.000 mean=nan
# size= 100 dens=1.0 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=0.179 | reach=1.000 pos=1.000 mean=652.1630303030303
# size= 100 dens=1.0 noise=0.5 neg=True | algo=bellman-ford neg_cycle=True sec=0.001 | reach=0.000 pos=0.000 mean=nan
# size= 100 dens=1.0 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=0.183 | reach=1.000 pos=1.000 mean=715.7495959595959
# size= 100 dens=1.0 noise=0.8 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size= 200 dens=0.2 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=0.323 | reach=1.000 pos=1.000 mean=558.7392713567839
# size= 200 dens=0.2 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=0.365 | reach=1.000 pos=1.000 mean=558.7392713567839
# size= 200 dens=0.2 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=0.314 | reach=1.000 pos=1.000 mean=649.4022613065326
# size= 200 dens=0.2 noise=0.1 neg=True | algo=bellman-ford neg_cycle=True sec=0.002 | reach=0.000 pos=0.000 mean=nan
# size= 200 dens=0.2 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=0.321 | reach=1.000 pos=1.000 mean=897.257311557789
# size= 200 dens=0.2 noise=0.5 neg=True | algo=bellman-ford neg_cycle=True sec=0.001 | reach=0.000 pos=0.000 mean=nan
# size= 200 dens=0.2 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=0.320 | reach=1.000 pos=1.000 mean=1038.1510301507537
# size= 200 dens=0.2 noise=0.8 neg=True | algo=bellman-ford neg_cycle=True sec=0.001 | reach=0.000 pos=0.000 mean=nan
# size= 200 dens=0.5 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=0.728 | reach=1.000 pos=1.000 mean=520.3441959798995
# size= 200 dens=0.5 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=0.710 | reach=1.000 pos=1.000 mean=520.3441959798995
# size= 200 dens=0.5 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=0.735 | reach=1.000 pos=1.000 mean=572.7704020100502
# size= 200 dens=0.5 noise=0.1 neg=True | algo=bellman-ford neg_cycle=True sec=0.002 | reach=0.000 pos=0.000 mean=nan
# size= 200 dens=0.5 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=0.741 | reach=1.000 pos=1.000 mean=710.93608040201
# size= 200 dens=0.5 noise=0.5 neg=True | algo=bellman-ford neg_cycle=True sec=0.001 | reach=0.000 pos=0.000 mean=nan
# size= 200 dens=0.5 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=0.769 | reach=1.000 pos=1.000 mean=790.3031658291458
# size= 200 dens=0.5 noise=0.8 neg=True | algo=bellman-ford neg_cycle=True sec=0.001 | reach=0.000 pos=0.000 mean=nan
# size= 200 dens=0.8 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=1.160 | reach=1.000 pos=1.000 mean=516.39608040201
# size= 200 dens=0.8 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=1.139 | reach=1.000 pos=1.000 mean=516.39608040201
# size= 200 dens=0.8 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=1.196 | reach=1.000 pos=1.000 mean=553.5335929648242
# size= 200 dens=0.8 noise=0.1 neg=True | algo=bellman-ford neg_cycle=True sec=0.003 | reach=0.000 pos=0.000 mean=nan
# size= 200 dens=0.8 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=1.219 | reach=1.000 pos=1.000 mean=653.7360552763819
# size= 200 dens=0.8 noise=0.5 neg=True | algo=bellman-ford neg_cycle=True sec=0.001 | reach=0.000 pos=0.000 mean=nan
# size= 200 dens=0.8 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=1.194 | reach=1.000 pos=1.000 mean=712.3013819095478
# size= 200 dens=0.8 noise=0.8 neg=True | algo=bellman-ford neg_cycle=True sec=0.001 | reach=0.000 pos=0.000 mean=nan
# size= 200 dens=1.0 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=1.460 | reach=1.000 pos=1.000 mean=515.6912060301507
# size= 200 dens=1.0 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=1.387 | reach=1.000 pos=1.000 mean=515.6912060301507
# size= 200 dens=1.0 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=1.461 | reach=1.000 pos=1.000 mean=546.6255527638191
# size= 200 dens=1.0 noise=0.1 neg=True | algo=bellman-ford neg_cycle=True sec=0.002 | reach=0.000 pos=0.000 mean=nan
# size= 200 dens=1.0 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=1.517 | reach=1.000 pos=1.000 mean=630.9008793969849
# size= 200 dens=1.0 noise=0.5 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size= 200 dens=1.0 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=1.581 | reach=1.000 pos=1.000 mean=680.6992211055276
# size= 200 dens=1.0 noise=0.8 neg=True | algo=bellman-ford neg_cycle=True sec=0.000 | reach=0.000 pos=0.000 mean=nan
# size= 500 dens=0.2 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=5.981 | reach=1.000 pos=1.000 mean=540.1000040080161
# size= 500 dens=0.2 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=5.577 | reach=1.000 pos=1.000 mean=540.1000040080161
# size= 500 dens=0.2 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=5.954 | reach=1.000 pos=1.000 mean=613.4769378757516
# size= 500 dens=0.2 noise=0.1 neg=True | algo=bellman-ford neg_cycle=True sec=0.005 | reach=0.000 pos=0.000 mean=nan
# size= 500 dens=0.2 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=6.006 | reach=1.000 pos=1.000 mean=796.7064128256513
# size= 500 dens=0.2 noise=0.5 neg=True | algo=bellman-ford neg_cycle=True sec=0.001 | reach=0.000 pos=0.000 mean=nan
# size= 500 dens=0.2 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=5.970 | reach=1.000 pos=1.000 mean=899.1653146292585
# size= 500 dens=0.2 noise=0.8 neg=True | algo=bellman-ford neg_cycle=True sec=0.002 | reach=0.000 pos=0.000 mean=nan
# size= 500 dens=0.5 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=13.205 | reach=1.000 pos=1.000 mean=528.0722204408818
# size= 500 dens=0.5 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=11.672 | reach=1.000 pos=1.000 mean=528.0722204408818
# size= 500 dens=0.5 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=13.718 | reach=1.000 pos=1.000 mean=568.8300320641282
# size= 500 dens=0.5 noise=0.1 neg=True | algo=bellman-ford neg_cycle=True sec=0.002 | reach=0.000 pos=0.000 mean=nan
# size= 500 dens=0.5 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=14.504 | reach=1.000 pos=1.000 mean=670.8746292585171
# size= 500 dens=0.5 noise=0.5 neg=True | algo=bellman-ford neg_cycle=True sec=0.001 | reach=0.000 pos=0.000 mean=nan
# size= 500 dens=0.5 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=13.553 | reach=1.000 pos=1.000 mean=728.9852064128256
# size= 500 dens=0.5 noise=0.8 neg=True | algo=bellman-ford neg_cycle=True sec=0.001 | reach=0.000 pos=0.000 mean=nan
# size= 500 dens=0.8 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=19.726 | reach=1.000 pos=1.000 mean=526.7026573146293
# size= 500 dens=0.8 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=18.552 | reach=1.000 pos=1.000 mean=526.7026573146293
# size= 500 dens=0.8 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=20.597 | reach=1.000 pos=1.000 mean=555.4249098196393
# size= 500 dens=0.8 noise=0.1 neg=True | algo=bellman-ford neg_cycle=True sec=0.002 | reach=0.000 pos=0.000 mean=nan
# size= 500 dens=0.8 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=22.193 | reach=1.000 pos=1.000 mean=628.4790861723446
# size= 500 dens=0.8 noise=0.5 neg=True | algo=bellman-ford neg_cycle=True sec=0.002 | reach=0.000 pos=0.000 mean=nan
# size= 500 dens=0.8 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=21.052 | reach=1.000 pos=1.000 mean=670.9098396793587
# size= 500 dens=0.8 noise=0.8 neg=True | algo=bellman-ford neg_cycle=True sec=0.001 | reach=0.000 pos=0.000 mean=nan
# size= 500 dens=1.0 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=24.126 | reach=1.000 pos=1.000 mean=526.4295951903807
# size= 500 dens=1.0 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=23.740 | reach=1.000 pos=1.000 mean=526.4295951903807
# size= 500 dens=1.0 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=25.560 | reach=1.000 pos=1.000 mean=550.5679078156313
# size= 500 dens=1.0 noise=0.1 neg=True | algo=bellman-ford neg_cycle=True sec=0.002 | reach=0.000 pos=0.000 mean=nan
# size= 500 dens=1.0 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=27.230 | reach=1.000 pos=1.000 mean=612.5355511022044
# size= 500 dens=1.0 noise=0.5 neg=True | algo=bellman-ford neg_cycle=True sec=0.002 | reach=0.000 pos=0.000 mean=nan
# size= 500 dens=1.0 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=25.849 | reach=1.000 pos=1.000 mean=648.7897595190381
# size= 500 dens=1.0 noise=0.8 neg=True | algo=bellman-ford neg_cycle=True sec=0.001 | reach=0.000 pos=0.000 mean=nan
# size=1000 dens=0.2 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=46.842 | reach=1.000 pos=1.000 mean=530.265062062062
# size=1000 dens=0.2 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=47.193 | reach=1.000 pos=1.000 mean=530.265062062062
# size=1000 dens=0.2 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=49.360 | reach=1.000 pos=1.000 mean=589.5461711711712
# size=1000 dens=0.2 noise=0.1 neg=True | algo=bellman-ford neg_cycle=True sec=0.007 | reach=0.000 pos=0.000 mean=nan
# size=1000 dens=0.2 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=52.629 | reach=1.000 pos=1.000 mean=726.6932262262262
# size=1000 dens=0.2 noise=0.5 neg=True | algo=bellman-ford neg_cycle=True sec=0.002 | reach=0.000 pos=0.000 mean=nan
# size=1000 dens=0.2 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=47.462 | reach=1.000 pos=1.000 mean=801.7516066066066
# size=1000 dens=0.2 noise=0.8 neg=True | algo=bellman-ford neg_cycle=True sec=0.002 | reach=0.000 pos=0.000 mean=nan
# size=1000 dens=0.5 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=103.978 | reach=1.000 pos=1.000 mean=524.9188638638639
# size=1000 dens=0.5 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=101.556 | reach=1.000 pos=1.000 mean=524.9188638638639
# size=1000 dens=0.5 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=113.407 | reach=1.000 pos=1.000 mean=556.5395085085086
# size=1000 dens=0.5 noise=0.1 neg=True | algo=bellman-ford neg_cycle=True sec=0.008 | reach=0.000 pos=0.000 mean=nan
# size=1000 dens=0.5 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=121.872 | reach=1.000 pos=1.000 mean=631.0373693693693
# size=1000 dens=0.5 noise=0.5 neg=True | algo=bellman-ford neg_cycle=True sec=0.001 | reach=0.000 pos=0.000 mean=nan
# size=1000 dens=0.5 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=109.853 | reach=1.000 pos=1.000 mean=673.242990990991
# size=1000 dens=0.5 noise=0.8 neg=True | algo=bellman-ford neg_cycle=True sec=0.001 | reach=0.000 pos=0.000 mean=nan
# size=1000 dens=0.8 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=158.089 | reach=1.000 pos=1.000 mean=524.2418298298298
# size=1000 dens=0.8 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=169.991 | reach=1.000 pos=1.000 mean=524.2418298298298
# size=1000 dens=0.8 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=170.687 | reach=1.000 pos=1.000 mean=546.6768178178178
# size=1000 dens=0.8 noise=0.1 neg=True | algo=bellman-ford neg_cycle=True sec=0.007 | reach=0.000 pos=0.000 mean=nan
# size=1000 dens=0.8 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=184.720 | reach=1.000 pos=1.000 mean=600.2875755755756
# size=1000 dens=0.8 noise=0.5 neg=True | algo=bellman-ford neg_cycle=True sec=0.003 | reach=0.000 pos=0.000 mean=nan
# size=1000 dens=0.8 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=174.206 | reach=1.000 pos=1.000 mean=631.2520810810811
# size=1000 dens=0.8 noise=0.8 neg=True | algo=bellman-ford neg_cycle=True sec=0.003 | reach=0.000 pos=0.000 mean=nan
# size=1000 dens=1.0 noise=0.0 neg=False | algo=dijkstra     neg_cycle=False sec=202.638 | reach=1.000 pos=1.000 mean=524.0632912912913
# size=1000 dens=1.0 noise=0.0 neg=True | algo=bellman-ford neg_cycle=False sec=222.660 | reach=1.000 pos=1.000 mean=524.0632912912913
# size=1000 dens=1.0 noise=0.1 neg=False | algo=dijkstra     neg_cycle=False sec=209.513 | reach=1.000 pos=1.000 mean=543.0378838838839
# size=1000 dens=1.0 noise=0.1 neg=True | algo=bellman-ford neg_cycle=True sec=0.006 | reach=0.000 pos=0.000 mean=nan
# size=1000 dens=1.0 noise=0.5 neg=False | algo=dijkstra     neg_cycle=False sec=222.168 | reach=1.000 pos=1.000 mean=588.5457597597598
# size=1000 dens=1.0 noise=0.5 neg=True | algo=bellman-ford neg_cycle=True sec=0.004 | reach=0.000 pos=0.000 mean=nan
# size=1000 dens=1.0 noise=0.8 neg=False | algo=dijkstra     neg_cycle=False sec=210.113 | reach=1.000 pos=1.000 mean=615.0283953953954
# size=1000 dens=1.0 noise=0.8 neg=True | algo=bellman-ford neg_cycle=True sec=0.003 | reach=0.000 pos=0.000 mean=nan
# Collected results: 224 rows

# %%
import csv
from datetime import datetime

if results:
    out_path = f"results_lab3_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
    fieldnames = list(results[0].keys())
    with open(out_path, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(results)
    print(f"Saved {len(results)} rows to {out_path}")
else:
    print("No results to save. Run the experiment loop first.")
# Out:
# Saved 224 rows to results_lab3_20251121_223557.csv
